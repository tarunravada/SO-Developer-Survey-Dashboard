# %%
import pandas as pd

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_csv('data/survey_results_public.csv')
print(df.shape)
# Out:
# (73268, 79)

# %%
df = df[df['Country'] == 'United States of America']
print(df.shape)
# Out:
# (13543, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13543 entries, 4 to 73265
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      13543 non-null  int64
#  1   MainBranch                      13543 non-null  object
#  2   Employment                      13533 non-null  object
#  3   RemoteWork                      11629 non-null  object
#  4   CodingActivities                11628 non-null  object
#  5   EdLevel                         13515 non-null  object
#  6   LearnCode                       13519 non-null  object
#  7   LearnCodeOnline                 9331 non-null   object
#  8   LearnCodeCoursesCert            4446 non-null   object
#  9   YearsCode                       13476 non-null  object
#  10  YearsCodePro                    10723 non-null  object
#  11  DevType                         11916 non-null  object
#  12  OrgSize                         10524 non-null  object
#  13  PurchaseInfluence               10531 non-null  object
#  14  BuyNewTool                      12827 non-null  object
#  15  Country                         13543 non-null  object
#  16  Currency                        10557 non-null  object
#  17  CompTotal                       8780 non-null   float64
#  18  CompFreq                        9241 non-null   object
#  19  LanguageHaveWorkedWith          13448 non-null  object
#  20  LanguageWantToWorkWith          12604 non-null  object
#  21  DatabaseHaveWorkedWith          10968 non-null  object
#  22  DatabaseWantToWorkWith          9016 non-null   object
#  23  PlatformHaveWorkedWith          9916 non-null   object
#  24  PlatformWantToWorkWith          7876 non-null   object
#  25  WebframeHaveWorkedWith          9903 non-null   object
#  26  WebframeWantToWorkWith          8355 non-null   object
#  27  MiscTechHaveWorkedWith          8326 non-null   object
#  28  MiscTechWantToWorkWith          6669 non-null   object
#  29  ToolsTechHaveWorkedWith         10266 non-null  object
#  30  ToolsTechWantToWorkWith         8523 non-null   object
#  31  NEWCollabToolsHaveWorkedWith    13312 non-null  object
#  32  NEWCollabToolsWantToWorkWith    11979 non-null  object
#  33  OpSysProfessional use           12337 non-null  object
#  34  OpSysPersonal use               13435 non-null  object
#  35  VersionControlSystem            13487 non-null  object
#  36  VCInteraction                   13036 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  8731 non-null   object
#  40  OfficeStackAsyncWantToWorkWith  5443 non-null   object
#  41  OfficeStackSyncHaveWorkedWith   12332 non-null  object
#  42  OfficeStackSyncWantToWorkWith   9428 non-null   object
#  43  Blockchain                      13496 non-null  object
#  44  NEWSOSites                      13493 non-null  object
#  45  SOVisitFreq                     13443 non-null  object
#  46  SOAccount                       13512 non-null  object
#  47  SOPartFreq                      10651 non-null  object
#  48  SOComm                          13493 non-null  object
#  49  Age                             13315 non-null  object
#  50  Gender                          13294 non-null  object
#  51  Trans                           13246 non-null  object
#  52  Sexuality                       12744 non-null  object
#  53  Ethnicity                       13052 non-null  object
#  54  Accessibility                   12831 non-null  object
#  55  MentalHealth                    12731 non-null  object
#  56  TBranch                         10828 non-null  object
#  57  ICorPM                          7176 non-null   object
#  58  WorkExp                         7246 non-null   float64
#  59  Knowledge_1                     7214 non-null   object
#  60  Knowledge_2                     7180 non-null   object
#  61  Knowledge_3                     7161 non-null   object
#  62  Knowledge_4                     7159 non-null   object
#  63  Knowledge_5                     7148 non-null   object
#  64  Knowledge_6                     7152 non-null   object
#  65  Knowledge_7                     7155 non-null   object
#  66  Frequency_1                     7109 non-null   object
#  67  Frequency_2                     7122 non-null   object
#  68  Frequency_3                     7068 non-null   object
#  69  TimeSearching                   7171 non-null   object
#  70  TimeAnswering                   7152 non-null   object
#  71  Onboarding                      7111 non-null   object
#  72  ProfessionalTech                7025 non-null   object
#  73  TrueFalse_1                     7174 non-null   object
#  74  TrueFalse_2                     7160 non-null   object
#  75  TrueFalse_3                     7153 non-null   object
#  76  SurveyLength                    13333 non-null  object
#  77  SurveyEase                      13368 non-null  object
#  78  ConvertedCompYearly             8707 non-null   float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 8.3+ MB

# %%
df.sample(5).T
# Out:
#                                                                             21902  \
# ResponseId                                                                  21903
# MainBranch                                         I am a developer by profession
# Employment                                                    Employed, full-time
# RemoteWork                                   Hybrid (some remote, some in-person)
# CodingActivities                                   Hobby;Bootstrapping a business
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                       Other online resources (e.g., videos, blogs, f...
# LearnCodeOnline                 Technical documentation;Blogs;Stack Overflow;V...
# LearnCodeCoursesCert                                                          NaN
# YearsCode                                                                       9
# YearsCodePro                                                                    4
# DevType                                                      Developer, front-end
# OrgSize                                                  5,000 to 9,999 employees
# PurchaseInfluence                                           I have some influence
# BuyNewTool                      Start a free trial;Ask developers I know/work ...
# Country                                                  United States of America
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                300000.0
# CompFreq                                                                   Yearly
# LanguageHaveWorkedWith                             HTML/CSS;JavaScript;TypeScript
# LanguageWantToWorkWith                             HTML/CSS;JavaScript;TypeScript
# DatabaseHaveWorkedWith                                                      MySQL
# DatabaseWantToWorkWith                                                        NaN
# PlatformHaveWorkedWith                                                        AWS
# PlatformWantToWorkWith                                                        AWS
# WebframeHaveWorkedWith                                                    Node.js
# WebframeWantToWorkWith                                             Node.js;Vue.js
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                           Flow;Homebrew;npm;Unity 3D;Yarn
# ToolsTechWantToWorkWith                                     Homebrew;npm;Unity 3D
# NEWCollabToolsHaveWorkedWith                               Vim;Visual Studio Code
# NEWCollabToolsWantToWorkWith                               Vim;Visual Studio Code
# OpSysProfessional use                                                       macOS
# OpSysPersonal use                 macOS;Windows;Windows Subsystem for Linux (WSL)
# VersionControlSystem                                                          Git
# VCInteraction                   Command-line;Version control hosting service w...
# VCHostingPersonal use                                                         NaN
# VCHostingProfessional use                                                     NaN
# OfficeStackAsyncHaveWorkedWith       Asana;Confluence;Jira Work Management;Notion
# OfficeStackAsyncWantToWorkWith                                   Asana;Confluence
# OfficeStackSyncHaveWorkedWith                                          Slack;Zoom
# OfficeStackSyncWantToWorkWith                                          Slack;Zoom
# Blockchain                                                            Unfavorable
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                                  A few times per week
# SOAccount                                                                     Yes
# SOPartFreq                                    Less than once per month or monthly
# SOComm                                                              Yes, somewhat
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                                    White;North American
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# TBranch                                                                        No
# ICorPM                                                                        NaN
# WorkExp                                                                       NaN
# Knowledge_1                                                                   NaN
# Knowledge_2                                                                   NaN
# Knowledge_3                                                                   NaN
# Knowledge_4                                                                   NaN
# Knowledge_5                                                                   NaN
# Knowledge_6                                                                   NaN
# Knowledge_7                                                                   NaN
# Frequency_1                                                                   NaN
# Frequency_2                                                                   NaN
# Frequency_3                                                                   NaN
# TimeSearching                                                                 NaN
# TimeAnswering                                                                 NaN
# Onboarding                                                                    NaN
# ProfessionalTech                                                              NaN
# TrueFalse_1                                                                   NaN
# TrueFalse_2                                                                   NaN
# TrueFalse_3                                                                   NaN
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                      300000.0
#
#                                                                             62282  \
# ResponseId                                                                  62283
# MainBranch                                         I am a developer by profession
# Employment                                                    Employed, full-time
# RemoteWork                                                           Fully remote
# CodingActivities                                    Hobby;School or academic work
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                       Books / Physical media;Other online resources ...
# LearnCodeOnline                 Technical documentation;Blogs;Written Tutorial...
# LearnCodeCoursesCert                                                          NaN
# YearsCode                                                                       5
# YearsCodePro                                                                    4
# DevType                         Engineer, data;Developer, full-stack;Developer...
# OrgSize                                                  1,000 to 4,999 employees
# PurchaseInfluence                                           I have some influence
# BuyNewTool                      Start a free trial;Visit developer communities...
# Country                                                  United States of America
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                100000.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith          Bash/Shell;HTML/CSS;JavaScript;PowerShell;Pyth...
# LanguageWantToWorkWith          C;C#;C++;Go;HTML/CSS;JavaScript;PowerShell;Pyt...
# DatabaseHaveWorkedWith               Microsoft SQL Server;PostgreSQL;Redis;SQLite
# DatabaseWantToWorkWith                                    PostgreSQL;Redis;SQLite
# PlatformHaveWorkedWith                                               Google Cloud
# PlatformWantToWorkWith                           AWS;Google Cloud;Microsoft Azure
# WebframeHaveWorkedWith                              Angular;Django;FastAPI;Vue.js
# WebframeWantToWorkWith          Angular;ASP.NET Core ;Django;FastAPI;Node.js;S...
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                  Homebrew
# ToolsTechWantToWorkWith                    Homebrew;npm;Pulumi;Terraform;Unity 3D
# NEWCollabToolsHaveWorkedWith                     Notepad++;Vim;Visual Studio Code
# NEWCollabToolsWantToWorkWith    IntelliJ;Neovim;Qt Creator;Vim;Visual Studio;V...
# OpSysProfessional use                                   Linux-based;macOS;Windows
# OpSysPersonal use                                       Linux-based;macOS;Windows
# VersionControlSystem                                                          Git
# VCInteraction                                            Code editor;Command-line
# VCHostingPersonal use                                                         NaN
# VCHostingProfessional use                                                     NaN
# OfficeStackAsyncHaveWorkedWith                                  Smartsheet;Trello
# OfficeStackAsyncWantToWorkWith                                                NaN
# OfficeStackSyncHaveWorkedWith                    Google Chat;Microsoft Teams;Zoom
# OfficeStackSyncWantToWorkWith                                         Google Chat
# Blockchain                                                              Favorable
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                   Less than once per month or monthly
# SOAccount                                                                     Yes
# SOPartFreq                                    Less than once per month or monthly
# SOComm                                                              Yes, somewhat
# Age                                                               35-44 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                           White;European;North American
# Accessibility                                              Or, in your own words:
# MentalHealth                    I have a mood or emotional disorder (e.g., dep...
# TBranch                                                                       Yes
# ICorPM                                                    Independent contributor
# WorkExp                                                                       8.0
# Knowledge_1                                                                 Agree
# Knowledge_2                                                              Disagree
# Knowledge_3                                            Neither agree nor disagree
# Knowledge_4                                                                 Agree
# Knowledge_5                                            Neither agree nor disagree
# Knowledge_6                                                              Disagree
# Knowledge_7                                                              Disagree
# Frequency_1                                                      3-5 times a week
# Frequency_2                                                      3-5 times a week
# Frequency_3                                                      3-5 times a week
# TimeSearching                                                 15-30 minutes a day
# TimeAnswering                                                 15-30 minutes a day
# Onboarding                                                          Somewhat long
# ProfessionalTech                DevOps function;Continuous integration (CI) an...
# TrueFalse_1                                                                    No
# TrueFalse_2                                                                    No
# TrueFalse_3                                                                   Yes
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                     1200000.0
#
#                                                                             50678  \
# ResponseId                                                                  50679
# MainBranch                                         I am a developer by profession
# Employment                                                    Employed, full-time
# RemoteWork                                                           Fully remote
# CodingActivities                                    Hobby;Freelance/contract work
# EdLevel                         Some college/university study without earning ...
# LearnCode                       Other online resources (e.g., videos, blogs, f...
# LearnCodeOnline                 Technical documentation;Blogs;Written Tutorial...
# LearnCodeCoursesCert                                                          NaN
# YearsCode                                                                       6
# YearsCodePro                                                                    6
# DevType                                 Developer, full-stack;Engineering manager
# OrgSize                                                      100 to 499 employees
# PurchaseInfluence                                           I have some influence
# BuyNewTool                      Visit developer communities like Stack Overflo...
# Country                                                  United States of America
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                185000.0
# CompFreq                                                                   Yearly
# LanguageHaveWorkedWith                                    HTML/CSS;JavaScript;SQL
# LanguageWantToWorkWith                      Go;HTML/CSS;JavaScript;SQL;TypeScript
# DatabaseHaveWorkedWith          Cloud Firestore;DynamoDB;Microsoft SQL Server;...
# DatabaseWantToWorkWith                                        DynamoDB;PostgreSQL
# PlatformHaveWorkedWith                                               AWS;Firebase
# PlatformWantToWorkWith                                                        AWS
# WebframeHaveWorkedWith                            Express;jQuery;Node.js;React.js
# WebframeWantToWorkWith                                           Node.js;React.js
# MiscTechHaveWorkedWith                                               React Native
# MiscTechWantToWorkWith                                          .NET;React Native
# ToolsTechHaveWorkedWith                        Docker;Homebrew;npm;Terraform;Yarn
# ToolsTechWantToWorkWith                                        npm;Terraform;Yarn
# NEWCollabToolsHaveWorkedWith                                   Visual Studio Code
# NEWCollabToolsWantToWorkWith                                   Visual Studio Code
# OpSysProfessional use                                                       macOS
# OpSysPersonal use                                                           macOS
# VersionControlSystem                                                          Git
# VCInteraction                   Code editor;Command-line;Dedicated version con...
# VCHostingPersonal use                                                         NaN
# VCHostingProfessional use                                                     NaN
# OfficeStackAsyncHaveWorkedWith  Airtable;Asana;Confluence;Jira Work Management...
# OfficeStackAsyncWantToWorkWith                    Confluence;Jira Work Management
# OfficeStackSyncHaveWorkedWith              Google Chat;Microsoft Teams;Slack;Zoom
# OfficeStackSyncWantToWorkWith                                               Slack
# Blockchain                                                            Unfavorable
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                       A few times per month or weekly
# SOAccount                                                                     Yes
# SOPartFreq                                    Less than once per month or monthly
# SOComm                                                              Yes, somewhat
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                                Bisexual
# Ethnicity                                                                   White
# Accessibility                                                   None of the above
# MentalHealth                    I have a concentration and/or memory disorder ...
# TBranch                                                                       Yes
# ICorPM                                                             People manager
# WorkExp                                                                       7.0
# Knowledge_1                                                        Strongly agree
# Knowledge_2                                                                 Agree
# Knowledge_3                                                              Disagree
# Knowledge_4                                                              Disagree
# Knowledge_5                                                              Disagree
# Knowledge_6                                            Neither agree nor disagree
# Knowledge_7                                                                 Agree
# Frequency_1                                                      1-2 times a week
# Frequency_2                                                      3-5 times a week
# Frequency_3                                                      3-5 times a week
# TimeSearching                                                 30-60 minutes a day
# TimeAnswering                                                60-120 minutes a day
# Onboarding                                                          Somewhat long
# ProfessionalTech                                                Automated testing
# TrueFalse_1                                                                   Yes
# TrueFalse_2                                                                   Yes
# TrueFalse_3                                                                    No
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                      185000.0
#
#                                                                             45509  \
# ResponseId                                                                  45510
# MainBranch                                         I am a developer by profession
# Employment                      Employed, full-time;Independent contractor, fr...
# RemoteWork                                   Hybrid (some remote, some in-person)
# CodingActivities                Hobby;Contribute to open-source projects;Boots...
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                       Books / Physical media;Other online resources ...
# LearnCodeOnline                 Technical documentation;Programming Games;Writ...
# LearnCodeCoursesCert                                                          NaN
# YearsCode                                                                      18
# YearsCodePro                                                                    6
# DevType                         Data scientist or machine learning specialist;...
# OrgSize                                                      100 to 499 employees
# PurchaseInfluence                                           I have some influence
# BuyNewTool                      Start a free trial;Visit developer communities...
# Country                                                  United States of America
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                300000.0
# CompFreq                                                                   Yearly
# LanguageHaveWorkedWith          Bash/Shell;C;C#;C++;HTML/CSS;Java;JavaScript;K...
# LanguageWantToWorkWith          Bash/Shell;C;C#;C++;HTML/CSS;Java;JavaScript;K...
# DatabaseHaveWorkedWith          DynamoDB;Elasticsearch;MariaDB;MongoDB;MySQL;P...
# DatabaseWantToWorkWith          DynamoDB;Elasticsearch;MariaDB;MongoDB;MySQL;P...
# PlatformHaveWorkedWith                        AWS;Firebase;Microsoft Azure;VMware
# PlatformWantToWorkWith                                                        AWS
# WebframeHaveWorkedWith          Angular;Angular.js;FastAPI;jQuery;Next.js;Node...
# WebframeWantToWorkWith          Angular;Angular.js;FastAPI;Next.js;Node.js;Nux...
# MiscTechHaveWorkedWith          Cordova;Flutter;NumPy;Pandas;React Native;Spri...
# MiscTechWantToWorkWith          NumPy;Pandas;React Native;TensorFlow;Torch/PyT...
# ToolsTechHaveWorkedWith         Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal...
# ToolsTechWantToWorkWith         Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal...
# NEWCollabToolsHaveWorkedWith    Android Studio;Eclipse;IntelliJ;Nano;NetBeans;...
# NEWCollabToolsWantToWorkWith         Android Studio;Nano;Visual Studio Code;Xcode
# OpSysProfessional use                                           Linux-based;macOS
# OpSysPersonal use                                               Linux-based;macOS
# VersionControlSystem                                                          Git
# VCInteraction                                            Code editor;Command-line
# VCHostingPersonal use                                                         NaN
# VCHostingProfessional use                                                     NaN
# OfficeStackAsyncHaveWorkedWith           Airtable;Confluence;Jira Work Management
# OfficeStackAsyncWantToWorkWith           Airtable;Confluence;Jira Work Management
# OfficeStackSyncHaveWorkedWith              Google Chat;Microsoft Teams;Slack;Zoom
# OfficeStackSyncWantToWorkWith              Google Chat;Microsoft Teams;Slack;Zoom
# Blockchain                                                         Very favorable
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                                  Daily or almost daily
# SOComm                                                            Yes, definitely
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                                   Asian;Southeast Asian
# Accessibility                   I am unable to / find it difficult to walk or ...
# MentalHealth                    I have a mood or emotional disorder (e.g., dep...
# TBranch                                                                       Yes
# ICorPM                                                    Independent contributor
# WorkExp                                                                       6.0
# Knowledge_1                                                              Disagree
# Knowledge_2                                                     Strongly disagree
# Knowledge_3                                                                 Agree
# Knowledge_4                                                        Strongly agree
# Knowledge_5                                                        Strongly agree
# Knowledge_6                                                        Strongly agree
# Knowledge_7                                                                 Agree
# Frequency_1                                                                 Never
# Frequency_2                                                      1-2 times a week
# Frequency_3                                                                 Never
# TimeSearching                                                60-120 minutes a day
# TimeAnswering                                                 15-30 minutes a day
# Onboarding                                                         Somewhat short
# ProfessionalTech                Innersource initiative;DevOps function;Microse...
# TrueFalse_1                                                                   Yes
# TrueFalse_2                                                                    No
# TrueFalse_3                                                                   Yes
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                      300000.0
#
#                                                                             15544
# ResponseId                                                                  15545
# MainBranch                                         I am a developer by profession
# Employment                                                    Employed, full-time
# RemoteWork                                   Hybrid (some remote, some in-person)
# CodingActivities                                                            Hobby
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# LearnCode                         Online Courses or Certification;Coding Bootcamp
# LearnCodeOnline                                                               NaN
# LearnCodeCoursesCert                                           Coursera;Udemy;edX
# YearsCode                                                                       3
# YearsCodePro                                                     Less than 1 year
# DevType                                                     Developer, full-stack
# OrgSize                                                      100 to 499 employees
# PurchaseInfluence                                   I have little or no influence
# BuyNewTool                      Start a free trial;Visit developer communities...
# Country                                                  United States of America
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                     NaN
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith                                          JavaScript;Python
# LanguageWantToWorkWith                                          JavaScript;Python
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                    PostgreSQL;Redis;SQLite
# PlatformHaveWorkedWith                                                        AWS
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                   FastAPI;Node.js;React.js
# WebframeWantToWorkWith                                           FastAPI;React.js
# MiscTechHaveWorkedWith                                                     Pandas
# MiscTechWantToWorkWith                                  NumPy;Pandas;Scikit-learn
# ToolsTechHaveWorkedWith                                                Docker;npm
# ToolsTechWantToWorkWith                                                Docker;npm
# NEWCollabToolsHaveWorkedWith                   IPython/Jupyter;Visual Studio Code
# NEWCollabToolsWantToWorkWith                                                  NaN
# OpSysProfessional use                                                 Linux-based
# OpSysPersonal use                                                           macOS
# VersionControlSystem                                                          Git
# VCInteraction                                            Code editor;Command-line
# VCHostingPersonal use                                                         NaN
# VCHostingProfessional use                                                     NaN
# OfficeStackAsyncHaveWorkedWith                               Jira Work Management
# OfficeStackAsyncWantToWorkWith                               Jira Work Management
# OfficeStackSyncHaveWorkedWith                                          Slack;Zoom
# OfficeStackSyncWantToWorkWith                                          Slack;Zoom
# Blockchain                                                            Indifferent
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                                  A few times per week
# SOAccount                                                                     Yes
# SOPartFreq                                    Less than once per month or monthly
# SOComm                                                             No, not really
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                                 European;North American
# Accessibility                                                   None of the above
# MentalHealth                                           I have an anxiety disorder
# TBranch                                                                        No
# ICorPM                                                                        NaN
# WorkExp                                                                       NaN
# Knowledge_1                                                                   NaN
# Knowledge_2                                                                   NaN
# Knowledge_3                                                                   NaN
# Knowledge_4                                                                   NaN
# Knowledge_5                                                                   NaN
# Knowledge_6                                                                   NaN
# Knowledge_7                                                                   NaN
# Frequency_1                                                                   NaN
# Frequency_2                                                                   NaN
# Frequency_3                                                                   NaN
# TimeSearching                                                                 NaN
# TimeAnswering                                                                 NaN
# Onboarding                                                                    NaN
# ProfessionalTech                                                              NaN
# TrueFalse_1                                                                   NaN
# TrueFalse_2                                                                   NaN
# TrueFalse_3                                                                   NaN
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                           NaN
